# %%
import akshare as ak
covid_19_area_search_df = ak.covid_19_area_search(province="四川省", city="成都市", district="高新区")
print(covid_19_area_search_df)
# Out:
#    province city district show_address      full_address cnt_sum_certain
# 0       四川省  成都市      高新区       时代锦城酒店   四川省成都市高新区时代锦城酒店              -1
# 1       四川省  成都市      高新区      天府长城柏南郡  四川省成都市高新区天府长城柏南郡              -1
# 2       四川省  成都市      高新区       中德英伦联邦   四川省成都市高新区中德英伦联邦              -1
# 3       四川省  成都市      高新区         成达佳园     四川省成都市高新区成达佳园              -1
# 4       四川省  成都市      高新区         招商玺悦     四川省成都市高新区招商玺悦              -1
# ..      ...  ...      ...          ...               ...             ...
# 9       四川省  成都市      高新区      神仙树大院4期  四川省成都市高新区神仙树大院4期              -1
# 10      四川省  成都市      高新区          乐颂居      四川省成都市高新区乐颂居              -1
# 11      四川省  成都市      高新区         景熙酒店     四川省成都市高新区景熙酒店              -1
# 12      四川省  成都市      高新区      维也纳国际酒店  四川省成都市高新区维也纳国际酒店              -1
# 13      四川省  成都市      高新区       龙湖时代天街   四川省成都市高新区龙湖时代天街              -1
#
# [14 rows x 6 columns]

# %%
import akshare as ak
covid_19_area_detail_df = ak.covid_19_area_detail()
print(covid_19_area_detail_df)
# Out:
# 100%|██████████| 1134/1134 [06:21<00:00,  2.97it/s]
#      province        city district show_address            full_address  \
# 0         云南省         玉溪市      红塔区    大石板社区秧草塘村  云南省玉溪市红塔区北城街道大石板社区秧草塘村
# 1         云南省         玉溪市      红塔区         华瑞小区    云南省玉溪市红塔区红塔大道50号华瑞小区
# 2         云南省         玉溪市      红塔区        玉景苑小区          云南省玉溪市红塔区玉景苑小区
# 3         云南省  德宏傣族景颇族自治州      瑞丽市       五缘玉城小区  云南省德宏傣族景颇族自治州瑞丽市五缘玉城小区
# 4         云南省         昆明市      东川区       黄包谷地小组      云南省昆明市东川区乌龙镇黄包谷地小组
# ...       ...         ...      ...          ...                     ...
# 6870  宁夏回族自治区         吴忠市      同心县          河湾村     宁夏回族自治区吴忠市同心县韦州镇河湾村
# 6871  宁夏回族自治区         吴忠市     青铜峡市          大沟村       宁夏回族自治区青铜峡市邵岗镇大沟村
# 6872  宁夏回族自治区         固原市      隆德县          红堡村     宁夏回族自治区固原市隆德县观庄乡红堡村
# 6873  宁夏回族自治区         银川市      灵武市          宁东镇        宁夏回族自治区银川市灵武市宁东镇
# 6874  宁夏回族自治区         中卫市      中宁县         大战场镇       宁夏回族自治区中卫市中宁县大战场镇
#
#      cnt_sum_certain
# 0                  2
# 1                  4
# 2                  1
# 3                  1
# 4                 -1
# ...              ...
# 6870               1
# 6871               4
# 6872               1
# 6873               1
# 6874               1
#
# [6875 rows x 6 columns]

# %%
import akshare as ak
covid_19_area_detail_df_2 = ak.covid_19_area_detail()
print(covid_19_area_detail_df_2)
# Out:
# 100%|██████████| 1134/1134 [04:49<00:00,  3.91it/s]
#      province        city district show_address            full_address  \
# 0         云南省         玉溪市      红塔区    大石板社区秧草塘村  云南省玉溪市红塔区北城街道大石板社区秧草塘村
# 1         云南省         玉溪市      红塔区         华瑞小区    云南省玉溪市红塔区红塔大道50号华瑞小区
# 2         云南省         玉溪市      红塔区        玉景苑小区          云南省玉溪市红塔区玉景苑小区
# 3         云南省  德宏傣族景颇族自治州      瑞丽市       五缘玉城小区  云南省德宏傣族景颇族自治州瑞丽市五缘玉城小区
# 4         云南省         昆明市      东川区       黄包谷地小组      云南省昆明市东川区乌龙镇黄包谷地小组
# ...       ...         ...      ...          ...                     ...
# 6870  宁夏回族自治区         吴忠市      同心县          河湾村     宁夏回族自治区吴忠市同心县韦州镇河湾村
# 6871  宁夏回族自治区         吴忠市     青铜峡市          大沟村       宁夏回族自治区青铜峡市邵岗镇大沟村
# 6872  宁夏回族自治区         固原市      隆德县          红堡村     宁夏回族自治区固原市隆德县观庄乡红堡村
# 6873  宁夏回族自治区         银川市      灵武市          宁东镇        宁夏回族自治区银川市灵武市宁东镇
# 6874  宁夏回族自治区         中卫市      中宁县         大战场镇       宁夏回族自治区中卫市中宁县大战场镇
#
#      cnt_sum_certain
# 0                  2
# 1                  4
# 2                  1
# 3                  1
# 4                 -1
# ...              ...
# 6870               1
# 6871               4
# 6872               1
# 6873               1
# 6874               1
#
# [6875 rows x 6 columns]

# %%
a = covid_19_area_detail_df_2.size

# %%
df = covid_19_area_detail_df_2
df.index,df.columns
# Out:
# (RangeIndex(start=0, stop=6875, step=1),
#  Index(['province', 'city', 'district', 'show_address', 'full_address',
#         'cnt_sum_certain'],
#        dtype='object'))

# %%
import pandas as pd
from pandas import ExcelWriter
with ExcelWriter('around.xlsx') as writer:
    df.to_excel(writer)
